# %% [markdown]
# # Setup

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Read data

# %%
data_dir = "../EDA/data/"

careerbuilder = pd.read_json(data_dir + 'careerbuilder')
mywork = pd.read_json(data_dir + 'mywork')
topcv = pd.read_json(data_dir + 'topcv')

cols_of_careerbuilder = ['_id', 'url', 'title', 'update_time', 'img_url', 'sectors',
       'application_deadline', 'salary', 'job_formality',
       'job_experience_years', 'required_gender_specific', 'job_attributes',
       'job_descriptions', 'job_requirements', 'company_name',
       'company_address', 'company_url', 'timestampISOdate']

cols_of_topcv = ['_id', 'url', 'title', 'img_url', 'sectors', 'application_deadline',
       'salary', 'job_attributes', 'job_formality', 'required_gender_specific',
       'job_experience_years', 'job_descriptions', 'job_requirements',
       'company_name', 'company_address', 'company_url', 'timestampISOdate']

cols = ['sectors', 'salary', 'job_attributes', 'job_formality',
       'required_gender_specific', 'job_experience_years', 'job_requirements',
       'company_name', 'company_address', 'source']

topcv['source'] = 'topcv'

dataCenter = topcv
dataCenter = dataCenter[cols]

# %%
pred_data = pd.read_csv(data_dir + "pred_data.csv")

# %%
__data = dataCenter.copy()

# %% [markdown]
# # Ranking

# %%
ranked_data = pred_data.copy()

a = 111
b = -11
c = -9

ranked_data['overall_score']\
    = a*ranked_data['salary_prediction']\
    + b*ranked_data['job_experience_years']\
    + c*ranked_data['required_gender_specific']

ranked_data
# Out:
#       salary_label  job_attributes  job_formality  required_gender_specific  \
# 0                2               3              2                         2
# 1                2               3              2                         2
# 2                7               3              2                         2
# 3                2               3              2                         3
# 4                5               3              2                         2
# ...            ...             ...            ...                       ...
# 8968             0               3              2                         2
# 8969             3               3              2                         1
# 8970             2               3              2                         1
# 8971             3               3              6                         2
# 8972             3               3              2                         1
#
#       job_experience_years  salary_prediction  overall_score
# 0                        2                  2            182
# 1                        3                  2            171
# 2                        2                  7            737
# 3                        2                  2            173
# 4                        3                  5            504
# ...                    ...                ...            ...
# 8968                     3                  2            171
# 8969                     3                  3            291
# 8970                     4                  2            169
# 8971                     4                  3            271
# 8972                     3                  3            291
#
# [8973 rows x 7 columns]

# %%
__data['overall_score'] = ranked_data['overall_score']
__data = __data.sort_values(by='overall_score', ascending=False).reset_index(drop=True)
__data
# Out:
#                                                 sectors  \
# 0     [Bất động sản, Bảo hiểm, Chứng khoán / Vàng / ...
# 1         [Kinh doanh / Bán hàng, Bất động sản, Tư vấn]
# 2            [Tư vấn, Bất động sản, Dịch vụ khách hàng]
# 3     [Kinh doanh / Bán hàng, Bảo hiểm, Hành chính /...
# 4     [Quản lý điều hành, Công nghệ cao, Marketing /...
# ...                                                 ...
# 8968                                          [Nhân sự]
# 8969                  [Thời trang, Công nghệ thông tin]
# 8970  [Kế toán / Kiểm toán, Ngân hàng / Tài chính, T...
# 8971  [Kinh doanh / Bán hàng, Thời trang, Bán lẻ / b...
# 8972  [Công nghệ thông tin, Công nghệ cao, IT phần mềm]
#
#                                                  salary  job_attributes  \
# 0     {'label': 'Trên 30 triệu', 'salary': 'Trên 30 ...  Toàn thời gian
# 1     {'label': 'Trên 30 triệu', 'salary': 'Tới 50 t...  Toàn thời gian
# 2     {'label': 'Trên 30 triệu', 'salary': 'Tới 30 t...  Toàn thời gian
# 3     {'label': 'Trên 30 triệu', 'salary': 'Tới 50 t...   Bán thời gian
# 4     {'label': 'Trên 30 triệu', 'salary': 'Trên 200...  Toàn thời gian
# ...                                                 ...             ...
# 8968  {'label': 'Dưới 5 triệu', 'salary': 'Tới 1,500...  Toàn thời gian
# 8969  {'label': 'Dưới 5 triệu', 'salary': '2,000-2,5...  Toàn thời gian
# 8970  {'label': 'Dưới 5 triệu', 'salary': 'Tới 2,500...  Toàn thời gian
# 8971  {'label': 'Dưới 5 triệu', 'salary': '1,500-2,5...  Toàn thời gian
# 8972  {'label': 'Dưới 5 triệu', 'salary': 'Tới 3,000...  Toàn thời gian
#
#            job_formality required_gender_specific job_experience_years  \
# 0              Nhân viên            Không yêu cầu           Dưới 1 năm
# 1              Nhân viên            Không yêu cầu           Dưới 1 năm
# 2              Nhân viên            Không yêu cầu           Dưới 1 năm
# 3       Trưởng/Phó phòng            Không yêu cầu           Dưới 1 năm
# 4              Nhân viên            Không yêu cầu           Dưới 1 năm
# ...                  ...                      ...                  ...
# 8968    Trưởng/Phó phòng            Không yêu cầu                5 năm
# 8969         Trưởng nhóm                      Nam                5 năm
# 8970  Quản lý / Giám sát            Không yêu cầu           Trên 5 năm
# 8971            Giám đốc            Không yêu cầu           Trên 5 năm
# 8972    Trưởng/Phó phòng                      Nam           Trên 5 năm
#
#                                        job_requirements  \
# 0     - Nghiêm túc trong công việc.- Chăm chỉ, nhanh...
# 1     Có Laptop cá nhân.\nKhông yêu cầu kinh nghiệm...
# 2     - Chịu khó học hỏi- Không có kinh nghiệm sẽ đư...
# 3     - Từ 25 tuổi trở lên. Có từ 1 năm kinh ...
# 4     At least 1 year of experience as the Community...
# ...                                                 ...
# 8968  • Proven working experience as HR Manager or H...
# 8969  Skills and abilitiesMust have● Code: Can write...
# 8970  Requirement:• Education: Graduate in finance/a...
# 8971  • Previous experience and/or qualifications in...
# 8972  # Must have- Bachelor’s degree in computer sci...
#
#                                            company_name  \
# 0               Công ty CPTM Địa ốc 5 sao Quảng Ninh
# 1                                    Tập Đoàn Danh Khôi
# 2                CÔNG TY CỔ PHẦN BẤT ĐỘNG SẢN FIRSTHOME
# 3     Công ty TNHH Bảo hiểm nhân thọ MB Ageas (MB Ag...
# 4                                Công ty TNHH Widi Tech
# ...                                                 ...
# 8968            Công ty Cổ phẩn Lotus Quality Assurance
# 8969                                       Swop Company
# 8970  Công ty cổ phần phương tiện điện thông minh Selex
# 8971                      Công ty TNHH thời trang Elise
# 8972       CÔNG TY CỔ PHẦN DAC DATA TECHNOLOGY VIỆT NAM
#
#                                         company_address source  overall_score
# 0     C1-06 KĐT Marine Plaza, P Hùng Thắng, TP Hạ...  topcv            748
# 1     105-107 Đường Nguyễn Công Trứ Phường Nguyễn Th...  topcv            748
# 2     Số 36 Đường số 6, Khu dân cư Him Lam, Phường T...  topcv            748
# 3                             27 Trần Phú, TP Thái Bình  topcv            748
# 4     Tầng 22F, Khu B, Tòa nhà HH4, Khu đô thị Mỹ Đì...  topcv            748
# ...                                                 ...    ...            ...
# 8968  Tầng 14 -17 , toà nhà văn phòng MD Complex, 68...  topcv             16
# 8969                               6 Võ Văn Kiệt Quận 1  topcv              7
# 8970       Nhà E4, Ngõ 18 Mạc Thái Tổ, Cầu Giấy, Hà Nội  topcv              5
# 8971        Tầng 8, Số 2 Tôn Thất Tùng, Đống Đa, Hà Nội  topcv              5
# 8972  Tầng 5, tòa Technosolf, ngõ 15, Duy Tân, Cầu G...  topcv             -4
#
# [8973 rows x 11 columns]

# %%
__data.to_csv(data_dir + "ranked_data.csv", index=False)
